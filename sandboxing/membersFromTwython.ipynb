# %%
import os
from twython import Twython



bearer_token = os.environ.get("BEARER_TOKEN")

# %%
APP_KEY = os.environ.get("API_KEY")
APP_SECRET = os.environ.get("API_SECRET_KEY")
ACCESS_TOKEN = os.environ.get("BEARER_TOKEN")

twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %%
twitter.search(q='hell')
# Out:
# {'statuses': [{'created_at': 'Thu Jul 15 19:44:10 +0000 2021',
#    'id': 1415759110029651972,
#    'id_str': '1415759110029651972',
#    'text': 'RT @JibbyD: Can someone explain to me how the Taliban, dressed in shalwars and chappals, ridicing CD70s are somehow just able to overrun fo…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JibbyD',
#       'name': 'Jibby',
#       'id': 469084216,
#       'id_str': '469084216',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 104517648,
#     'id_str': '104517648',
#     'name': 'Khansaab',
#     'screen_name': 'GumbyAKhan',
#     'location': 'Dubai, United Arab Emirates',
#     'description': 'Cricket, Fawad Alam, YK & Quetta Gladiators basicall. Occasional cricket writer published @ ET, Cricinfo, Cricingif. Risk & Management Consult by profession tho',
#     'url': 'https://t.co/FWiKWRMAav',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FWiKWRMAav',
#         'expanded_url': 'https://www.instagram.com/khaanqah/',
#         'display_url': 'instagram.com/khaanqah/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 591,
#     'friends_count': 322,
#     'listed_count': 21,
#     'created_at': 'Wed Jan 13 15:35:34 +0000 2010',
#     'favourites_count': 6406,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 61767,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1329326729412931585/KwJbjeZH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1329326729412931585/KwJbjeZH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104517648/1548093856',
#     'profile_link_color': '189458',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 15 17:38:15 +0000 2021',
#     'id': 1415727424881496064,
#     'id_str': '1415727424881496064',
#     'text': 'Can someone explain to me how the Taliban, dressed in shalwars and chappals, ridicing CD70s are somehow just able t… https://t.co/u416bW9zQT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u416bW9zQT',
#        'expanded_url': 'https://twitter.com/i/web/status/1415727424881496064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 469084216,
#      'id_str': '469084216',
#      'name': 'Jibby',
#      'screen_name': 'JibbyD',
#      'location': '',
#      'description': 'I make these memoji videos that some people find funny. You can find them all at the link below! #peshawarland',
#      'url': 'https://t.co/PryEvrM7Oy',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PryEvrM7Oy',
#          'expanded_url': 'http://instagram.com/peshawarland',
#          'display_url': 'instagram.com/peshawarland',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 10605,
#      'friends_count': 305,
#      'listed_count': 50,
#      'created_at': 'Fri Jan 20 06:41:07 +0000 2012',
#      'favourites_count': 28060,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 81273,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '030303',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1151649680620773376/pphYQXHy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1151649680620773376/pphYQXHy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/469084216/1619170644',
#      'profile_link_color': '038543',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 35,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:09 +0000 2021',
#    'id': 1415759107735396361,
#    'id_str': '1415759107735396361',
#    'text': 'The Godfather of TPLF @martinplaut says ‘European Union and Ethiopia clash over an air-bridge for aid to Tigray’ We… https://t.co/O2f88RrNPG',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'martinplaut',
#       'name': 'Martin Plaut',
#       'id': 174174847,
#       'id_str': '174174847',
#       'indices': [22, 34]}],
#     'urls': [{'url': 'https://t.co/O2f88RrNPG',
#       'expanded_url': 'https://twitter.com/i/web/status/1415759107735396361',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1415622822983094278,
#     'id_str': '1415622822983094278',
#     'name': 'Gemechu Sheleme',
#     'screen_name': 'sheleme',
#     'location': '',
#     'description': '#Human',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 112,
#     'listed_count': 0,
#     'created_at': 'Thu Jul 15 10:42:53 +0000 2021',
#     'favourites_count': 2,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1415623009294028801/hQKQ5asK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1415623009294028801/hQKQ5asK_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:09 +0000 2021',
#    'id': 1415759107177525254,
#    'id_str': '1415759107177525254',
#    'text': 'HELL NO!😂😂😂😂😂😂 https://t.co/EZG1KF4xOt',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/EZG1KF4xOt',
#       'expanded_url': 'https://twitter.com/TheNtilo/status/1415725536920342530',
#       'display_url': 'twitter.com/TheNtilo/statu…',
#       'indices': [15, 38]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1062834285848289280,
#     'id_str': '1062834285848289280',
#     'name': 'Natalia Tafadzwa Bukalia',
#     'screen_name': 'Natalia_Bukalia',
#     'location': 'Blantyre Malawi,Zimbabwe ',
#     'description': '🇲🇼🇿🇼❤',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4724,
#     'friends_count': 966,
#     'listed_count': 2,
#     'created_at': 'Wed Nov 14 22:26:55 +0000 2018',
#     'favourites_count': 13751,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 25148,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1414300737950126080/b3giGTXc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1414300737950126080/b3giGTXc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1062834285848289280/1621496845',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': 'a0583a9994e6bf1b',
#     'url': 'https://api.twitter.com/1.1/geo/id/a0583a9994e6bf1b.json',
#     'place_type': 'country',
#     'name': 'Malawi',
#     'full_name': 'Malawi',
#     'country_code': 'MW',
#     'country': 'Malawi',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[32.6718934, -17.1276504],
#        [35.92038, -17.1276504],
#        [35.92038, -9.3670837],
#        [32.6718934, -9.3670837]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1415725536920342530,
#    'quoted_status_id_str': '1415725536920342530',
#    'quoted_status': {'created_at': 'Thu Jul 15 17:30:45 +0000 2021',
#     'id': 1415725536920342530,
#     'id_str': '1415725536920342530',
#     'text': 'lemme go be a marketing lecturer, it’s always been my calling 🏃🏾 https://t.co/gxHupl7Pkg',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gxHupl7Pkg',
#        'expanded_url': 'https://twitter.com/cu_malawi/status/1415681528898592778',
#        'display_url': 'twitter.com/cu_malawi/stat…',
#        'indices': [65, 88]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 146148303,
#      'id_str': '146148303',
#      'name': 'Lord Timmy, 1st of His Name',
#      'screen_name': 'TheNtilo',
#      'location': 'Malawi',
#      'description': 'brand strategist',
#      'url': 'https://t.co/FuVRFVPKXr',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FuVRFVPKXr',
#          'expanded_url': 'https://www.timmy.mw',
#          'display_url': 'timmy.mw',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12479,
#      'friends_count': 1421,
#      'listed_count': 30,
#      'created_at': 'Thu May 20 18:21:33 +0000 2010',
#      'favourites_count': 8384,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 68289,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FCFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1411624543630864385/_xm7imhv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1411624543630864385/_xm7imhv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/146148303/1605552924',
#      'profile_link_color': '2E94B3',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': 'a0583a9994e6bf1b',
#      'url': 'https://api.twitter.com/1.1/geo/id/a0583a9994e6bf1b.json',
#      'place_type': 'country',
#      'name': 'Malawi',
#      'full_name': 'Malawi',
#      'country_code': 'MW',
#      'country': 'Malawi',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[32.6718934, -17.1276504],
#         [35.92038, -17.1276504],
#         [35.92038, -9.3670837],
#         [32.6718934, -9.3670837]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1415681528898592778,
#     'quoted_status_id_str': '1415681528898592778',
#     'retweet_count': 0,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:09 +0000 2021',
#    'id': 1415759106045054976,
#    'id_str': '1415759106045054976',
#    'text': 'RT @BLINDEDBYTHEL13: @lightersup9 @MilitaryStart4 @NoVaseline4you @BananasNuts1 @SUPERJOLLYGREE1 @GIANTMOOSEBALLS @HEREBEDRAGONS19 @THUNDER…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BLINDEDBYTHEL13',
#       'name': 'BLINDED BY THE LIGHT',
#       'id': 1349063624057384972,
#       'id_str': '1349063624057384972',
#       'indices': [3, 19]},
#      {'screen_name': 'lightersup9',
#       'name': 'LIGHTERSUP9',
#       'id': 1393273693372043268,
#       'id_str': '1393273693372043268',
#       'indices': [21, 33]},
#      {'screen_name': 'MilitaryStart4',
#       'name': 'MilitaryStart4',
#       'id': 1275843884409589761,
#       'id_str': '1275843884409589761',
#       'indices': [34, 49]},
#      {'screen_name': 'NoVaseline4you',
#       'name': 'NO VASELINE',
#       'id': 1162358438732718080,
#       'id_str': '1162358438732718080',
#       'indices': [50, 65]},
#      {'screen_name': 'BananasNuts1',
#       'name': 'DOG',
#       'id': 1349060197730410496,
#       'id_str': '1349060197730410496',
#       'indices': [66, 79]},
#      {'screen_name': 'SUPERJOLLYGREE1',
#       'name': 'SUPERJOLLYGREEN',
#       'id': 1327307310876811265,
#       'id_str': '1327307310876811265',
#       'indices': [80, 96]},
#      {'screen_name': 'GIANTMOOSEBALLS',
#       'name': 'MOOSE NUTS',
#       'id': 1296511270334627841,
#       'id_str': '1296511270334627841',
#       'indices': [97, 113]},
#      {'screen_name': 'HEREBEDRAGONS19',
#       'name': 'HERE BE DRAGONS',
#       'id': 1350823078201323520,
#       'id_str': '1350823078201323520',
#       'indices': [114, 130]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1393273693372043268,
#     'id_str': '1393273693372043268',
#     'name': 'LIGHTERSUP9',
#     'screen_name': 'lightersup9',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8,
#     'friends_count': 9,
#     'listed_count': 1,
#     'created_at': 'Fri May 14 18:35:24 +0000 2021',
#     'favourites_count': 12565,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 14731,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1393274788106362886/h6jHH1lj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1393274788106362886/h6jHH1lj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1393273693372043268/1621017671',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 15 19:43:05 +0000 2021',
#     'id': 1415758838205231107,
#     'id_str': '1415758838205231107',
#     'text': '@lightersup9 @MilitaryStart4 @NoVaseline4you @BananasNuts1 @SUPERJOLLYGREE1 @GIANTMOOSEBALLS @HEREBEDRAGONS19… https://t.co/S9GWDJfFFF',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'lightersup9',
#        'name': 'LIGHTERSUP9',
#        'id': 1393273693372043268,
#        'id_str': '1393273693372043268',
#        'indices': [0, 12]},
#       {'screen_name': 'MilitaryStart4',
#        'name': 'MilitaryStart4',
#        'id': 1275843884409589761,
#        'id_str': '1275843884409589761',
#        'indices': [13, 28]},
#       {'screen_name': 'NoVaseline4you',
#        'name': 'NO VASELINE',
#        'id': 1162358438732718080,
#        'id_str': '1162358438732718080',
#        'indices': [29, 44]},
#       {'screen_name': 'BananasNuts1',
#        'name': 'DOG',
#        'id': 1349060197730410496,
#        'id_str': '1349060197730410496',
#        'indices': [45, 58]},
#       {'screen_name': 'SUPERJOLLYGREE1',
#        'name': 'SUPERJOLLYGREEN',
#        'id': 1327307310876811265,
#        'id_str': '1327307310876811265',
#        'indices': [59, 75]},
#       {'screen_name': 'GIANTMOOSEBALLS',
#        'name': 'MOOSE NUTS',
#        'id': 1296511270334627841,
#        'id_str': '1296511270334627841',
#        'indices': [76, 92]},
#       {'screen_name': 'HEREBEDRAGONS19',
#        'name': 'HERE BE DRAGONS',
#        'id': 1350823078201323520,
#        'id_str': '1350823078201323520',
#        'indices': [93, 109]}],
#      'urls': [{'url': 'https://t.co/S9GWDJfFFF',
#        'expanded_url': 'https://twitter.com/i/web/status/1415758838205231107',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1415757411101589517,
#     'in_reply_to_status_id_str': '1415757411101589517',
#     'in_reply_to_user_id': 1393273693372043268,
#     'in_reply_to_user_id_str': '1393273693372043268',
#     'in_reply_to_screen_name': 'lightersup9',
#     'user': {'id': 1349063624057384972,
#      'id_str': '1349063624057384972',
#      'name': 'BLINDED BY THE LIGHT',
#      'screen_name': 'BLINDEDBYTHEL13',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 16,
#      'friends_count': 137,
#      'listed_count': 2,
#      'created_at': 'Tue Jan 12 18:40:21 +0000 2021',
#      'favourites_count': 20563,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 27489,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1381702077223727111/wEW3xbY8_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1381702077223727111/wEW3xbY8_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1349063624057384972/1610476967',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1415757411101589517,
#     'quoted_status_id_str': '1415757411101589517',
#     'quoted_status': {'created_at': 'Thu Jul 15 19:37:24 +0000 2021',
#      'id': 1415757411101589517,
#      'id_str': '1415757411101589517',
#      'text': '@MilitaryStart4 @BLINDEDBYTHEL13 @NoVaseline4you @BananasNuts1 @SUPERJOLLYGREE1 @GIANTMOOSEBALLS @HEREBEDRAGONS19… https://t.co/00xsNJUdS1',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'MilitaryStart4',
#         'name': 'MilitaryStart4',
#         'id': 1275843884409589761,
#         'id_str': '1275843884409589761',
#         'indices': [0, 15]},
#        {'screen_name': 'BLINDEDBYTHEL13',
#         'name': 'BLINDED BY THE LIGHT',
#         'id': 1349063624057384972,
#         'id_str': '1349063624057384972',
#         'indices': [16, 32]},
#        {'screen_name': 'NoVaseline4you',
#         'name': 'NO VASELINE',
#         'id': 1162358438732718080,
#         'id_str': '1162358438732718080',
#         'indices': [33, 48]},
#        {'screen_name': 'BananasNuts1',
#         'name': 'DOG',
#         'id': 1349060197730410496,
#         'id_str': '1349060197730410496',
#         'indices': [49, 62]},
#        {'screen_name': 'SUPERJOLLYGREE1',
#         'name': 'SUPERJOLLYGREEN',
#         'id': 1327307310876811265,
#         'id_str': '1327307310876811265',
#         'indices': [63, 79]},
#        {'screen_name': 'GIANTMOOSEBALLS',
#         'name': 'MOOSE NUTS',
#         'id': 1296511270334627841,
#         'id_str': '1296511270334627841',
#         'indices': [80, 96]},
#        {'screen_name': 'HEREBEDRAGONS19',
#         'name': 'HERE BE DRAGONS',
#         'id': 1350823078201323520,
#         'id_str': '1350823078201323520',
#         'indices': [97, 113]}],
#       'urls': [{'url': 'https://t.co/00xsNJUdS1',
#         'expanded_url': 'https://twitter.com/i/web/status/1415757411101589517',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [115, 138]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': 1415756361351245826,
#      'in_reply_to_status_id_str': '1415756361351245826',
#      'in_reply_to_user_id': 1275843884409589761,
#      'in_reply_to_user_id_str': '1275843884409589761',
#      'in_reply_to_screen_name': 'MilitaryStart4',
#      'user': {'id': 1393273693372043268,
#       'id_str': '1393273693372043268',
#       'name': 'LIGHTERSUP9',
#       'screen_name': 'lightersup9',
#       'location': '',
#       'description': '',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 8,
#       'friends_count': 9,
#       'listed_count': 1,
#       'created_at': 'Fri May 14 18:35:24 +0000 2021',
#       'favourites_count': 12565,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 14731,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1393274788106362886/h6jHH1lj_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1393274788106362886/h6jHH1lj_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1393273693372043268/1621017671',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'translator_type': 'none',
#       'withheld_in_countries': []},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': True,
#      'quoted_status_id': 1415756361351245826,
#      'quoted_status_id_str': '1415756361351245826',
#      'retweet_count': 3,
#      'favorite_count': 3,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1415757411101589517,
#    'quoted_status_id_str': '1415757411101589517',
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:08 +0000 2021',
#    'id': 1415759102899335173,
#    'id_str': '1415759102899335173',
#    'text': '@jt_vinny @Team_Penske @AustinCindric @NASCAR What you’re saying is that Blaney is one hell of a driver to use 3rd… https://t.co/rsKYgHlD2d',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jt_vinny',
#       'name': 'VinnyJT',
#       'id': 1361137860120899584,
#       'id_str': '1361137860120899584',
#       'indices': [0, 9]},
#      {'screen_name': 'Team_Penske',
#       'name': 'Team Penske',
#       'id': 50311625,
#       'id_str': '50311625',
#       'indices': [10, 22]},
#      {'screen_name': 'AustinCindric',
#       'name': 'Austin Cindric',
#       'id': 910326859,
#       'id_str': '910326859',
#       'indices': [23, 37]},
#      {'screen_name': 'NASCAR',
#       'name': 'NASCAR',
#       'id': 49153854,
#       'id_str': '49153854',
#       'indices': [38, 45]}],
#     'urls': [{'url': 'https://t.co/rsKYgHlD2d',
#       'expanded_url': 'https://twitter.com/i/web/status/1415759102899335173',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1415758967360393218,
#    'in_reply_to_status_id_str': '1415758967360393218',
#    'in_reply_to_user_id': 1363711487097724933,
#    'in_reply_to_user_id_str': '1363711487097724933',
#    'in_reply_to_screen_name': 'kyle15684197',
#    'user': {'id': 1363711487097724933,
#     'id_str': '1363711487097724933',
#     'name': 'kyle',
#     'screen_name': 'kyle15684197',
#     'location': 'South Dakota, USA',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 71,
#     'listed_count': 0,
#     'created_at': 'Mon Feb 22 04:45:45 +0000 2021',
#     'favourites_count': 1518,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 221,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1411739727292682241/ZzfVi1CY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1411739727292682241/ZzfVi1CY_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:07 +0000 2021',
#    'id': 1415759100923637761,
#    'id_str': '1415759100923637761',
#    'text': '@FaZeSway shut the hell up I wanna sue my barber shop https://t.co/nBenkhQRmR',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FaZeSway',
#       'name': 'FaZe Sway',
#       'id': 989983009339269120,
#       'id_str': '989983009339269120',
#       'indices': [0, 9]}],
#     'urls': [],
#     'media': [{'id': 1415759092539269121,
#       'id_str': '1415759092539269121',
#       'indices': [54, 77],
#       'media_url': 'http://pbs.twimg.com/media/E6XJZMZVIAEW_3N.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E6XJZMZVIAEW_3N.jpg',
#       'url': 'https://t.co/nBenkhQRmR',
#       'display_url': 'pic.twitter.com/nBenkhQRmR',
#       'expanded_url': 'https://twitter.com/COsLyUcfC1DYYpO/status/1415759100923637761/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1415759092539269121,
#       'id_str': '1415759092539269121',
#       'indices': [54, 77],
#       'media_url': 'http://pbs.twimg.com/media/E6XJZMZVIAEW_3N.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E6XJZMZVIAEW_3N.jpg',
#       'url': 'https://t.co/nBenkhQRmR',
#       'display_url': 'pic.twitter.com/nBenkhQRmR',
#       'expanded_url': 'https://twitter.com/COsLyUcfC1DYYpO/status/1415759100923637761/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1415298001548021762,
#    'in_reply_to_status_id_str': '1415298001548021762',
#    'in_reply_to_user_id': 989983009339269120,
#    'in_reply_to_user_id_str': '989983009339269120',
#    'in_reply_to_screen_name': 'FaZeSway',
#    'user': {'id': 1374215481356263425,
#     'id_str': '1374215481356263425',
#     'name': 'kashwayz on top',
#     'screen_name': 'COsLyUcfC1DYYpO',
#     'location': '',
#     'description': 'KASHDAMI A GOAT been a fan since 40k lol',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 16,
#     'listed_count': 0,
#     'created_at': 'Tue Mar 23 04:24:47 +0000 2021',
#     'favourites_count': 71,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 60,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1411567512672555016/eSTu-1Pc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1411567512672555016/eSTu-1Pc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1374215481356263425/1625378894',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:07 +0000 2021',
#    'id': 1415759100076511235,
#    'id_str': '1415759100076511235',
#    'text': '@ilkeekins Hell yah!!',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ilkeekins',
#       'name': 'ilke',
#       'id': 3075460573,
#       'id_str': '3075460573',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1415384832239042562,
#    'in_reply_to_status_id_str': '1415384832239042562',
#    'in_reply_to_user_id': 3075460573,
#    'in_reply_to_user_id_str': '3075460573',
#    'in_reply_to_screen_name': 'ilkeekins',
#    'user': {'id': 1410603589261697024,
#     'id_str': '1410603589261697024',
#     'name': 'Hunter Lear',
#     'screen_name': 'HunterLear2',
#     'location': '',
#     'description': 'Vegan / Poet / Writer • With vibrant love and letting go',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4,
#     'friends_count': 14,
#     'listed_count': 0,
#     'created_at': 'Thu Jul 01 14:18:14 +0000 2021',
#     'favourites_count': 14,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1410603755666493451/0RZGtssW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1410603755666493451/0RZGtssW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1410603589261697024/1625670755',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:07 +0000 2021',
#    'id': 1415759099225165824,
#    'id_str': '1415759099225165824',
#    'text': 'Not gone cap but what the hell is Sopp cash🤦🤣 https://t.co/gqLNyFckGq',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gqLNyFckGq',
#       'expanded_url': 'https://twitter.com/CashNasty/status/1415511953951232002',
#       'display_url': 'twitter.com/CashNasty/stat…',
#       'indices': [46, 69]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4903381895,
#     'id_str': '4903381895',
#     'name': 'Official SrKwando_13',
#     'screen_name': 'joakimnoahkwan',
#     'location': 'Chicago, IL',
#     'description': 'young artist with the music skills, art skills, and gaming who gives a passion for caring and supporting new things.....Music and More coming.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 176,
#     'friends_count': 223,
#     'listed_count': 0,
#     'created_at': 'Sat Feb 13 02:36:06 +0000 2016',
#     'favourites_count': 3026,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2738,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1378120310701064192/VxZBZno-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1378120310701064192/VxZBZno-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4903381895/1611064023',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1415511953951232002,
#    'quoted_status_id_str': '1415511953951232002',
#    'quoted_status': {'created_at': 'Thu Jul 15 03:22:03 +0000 2021',
#     'id': 1415511953951232002,
#     'id_str': '1415511953951232002',
#     'text': 'Lmfao Booker sopp to foul out on that play…wtf is the refs doing',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1596661453,
#      'id_str': '1596661453',
#      'name': '💯 Cash',
#      'screen_name': 'CashNasty',
#      'location': 'The Staples Center',
#      'description': '#2Hype x #100T ....Ima hooper not a hooper hooper... Business Inquiries: Cash@longhaulmgmt.com',
#      'url': 'https://t.co/Fqo1yF9XOe',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Fqo1yF9XOe',
#          'expanded_url': 'https://www.youtube.com/channel/UCvyTdLw8SkVmUcHYXSDEGwA',
#          'display_url': 'youtube.com/channel/UCvyTd…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1156477,
#      'friends_count': 1431,
#      'listed_count': 332,
#      'created_at': 'Mon Jul 15 20:00:01 +0000 2013',
#      'favourites_count': 10968,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 66567,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1412155011350634503/4AANjf6i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1412155011350634503/4AANjf6i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1596661453/1623439947',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 104,
#     'favorite_count': 2572,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:07 +0000 2021',
#    'id': 1415759098965020680,
#    'id_str': '1415759098965020680',
#    'text': 'RT @ThePubliusUSA: The founders would have tried Donald Trump for treason. What the hell are we doing?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ThePubliusUSA',
#       'name': 'A Hopeful Citizen',
#       'id': 1113828112503115776,
#       'id_str': '1113828112503115776',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 343060110,
#     'id_str': '343060110',
#     'name': 'Leslieodd',
#     'screen_name': 'labountygreen',
#     'location': '',
#     'description': 'Midwestern flaming liberal, worker bee. I am sooo excited about Biden-Harris Administration. Go #JoeBiden #BLM #LGBTQ Fully Vaccinated! No DMs please.😷',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2312,
#     'friends_count': 3205,
#     'listed_count': 4,
#     'created_at': 'Wed Jul 27 00:40:00 +0000 2011',
#     'favourites_count': 58456,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 35636,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1296126264269590529/PxzRG9Y3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296126264269590529/PxzRG9Y3_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 15 16:48:13 +0000 2021',
#     'id': 1415714831177551873,
#     'id_str': '1415714831177551873',
#     'text': 'The founders would have tried Donald Trump for treason. What the hell are we doing?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
# ...
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/883359911257812992/weAuXqmy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883359911257812992/weAuXqmy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/716495980036685824/1548772146',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 15 17:20:31 +0000 2021',
#     'id': 1415722961793859588,
#     'id_str': '1415722961793859588',
#     'text': 'Capitalists are on TV admitting to you that scarcity and financial desperation are enforced, because otherwise why… https://t.co/OueEqK8Vf8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/OueEqK8Vf8',
#        'expanded_url': 'https://twitter.com/i/web/status/1415722961793859588',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': 1415722627025485833,
#     'in_reply_to_status_id_str': '1415722627025485833',
#     'in_reply_to_user_id': 1342500619140157443,
#     'in_reply_to_user_id_str': '1342500619140157443',
#     'in_reply_to_screen_name': 'SheReadsNews',
#     'user': {'id': 1342500619140157443,
#      'id_str': '1342500619140157443',
#      'name': 'I Like to Read the News',
#      'screen_name': 'SheReadsNews',
#      'location': 'The Great Wide Open',
#      'description': "There is no leftism that isn't anti-capitalist, anti-racist and anti-fascist. Pushing reactionary ideas isn't radical it just makes you a muppet for rich nazis.",
#      'url': 'https://t.co/X0b363Rf8W',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/X0b363Rf8W',
#          'expanded_url': 'https://www.ninaillingworth.com/',
#          'display_url': 'ninaillingworth.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 320,
#      'friends_count': 344,
#      'listed_count': 0,
#      'created_at': 'Fri Dec 25 16:01:39 +0000 2020',
#      'favourites_count': 3824,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 5685,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1390591281118732289/nOo2w_47_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1390591281118732289/nOo2w_47_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1342500619140157443/1608913104',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:05 +0000 2021',
#    'id': 1415759093130612736,
#    'id_str': '1415759093130612736',
#    'text': 'RT @sheeyxo: if my man needs $70 imma send him 70 thousand hundred million dollars &amp; a hell cat',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sheeyxo',
#       'name': 'Shey',
#       'id': 1223686898511577088,
#       'id_str': '1223686898511577088',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1061947014,
#     'id_str': '1061947014',
#     'name': 'aaliyah marie',
#     'screen_name': 'marieeaaliyah',
#     'location': 'Arizona, USA',
#     'description': 'whats it to ya',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 213,
#     'friends_count': 269,
#     'listed_count': 1,
#     'created_at': 'Sat Jan 05 02:27:01 +0000 2013',
#     'favourites_count': 8196,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2768,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1410142490187821056/yDbjsUJZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1410142490187821056/yDbjsUJZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1061947014/1598747012',
#     'profile_link_color': 'F5ABB5',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 08 06:42:30 +0000 2021',
#     'id': 1413025684134432768,
#     'id_str': '1413025684134432768',
#     'text': 'if my man needs $70 imma send him 70 thousand hundred million dollars &amp; a hell cat',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1223686898511577088,
#      'id_str': '1223686898511577088',
#      'name': 'Shey',
#      'screen_name': 'sheeyxo',
#      'location': 'NM',
#      'description': 'Psych/ Criminology',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2532,
#      'friends_count': 1302,
#      'listed_count': 17,
#      'created_at': 'Sat Feb 01 19:17:53 +0000 2020',
#      'favourites_count': 11339,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 3640,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1415154271973101572/mXXFwyM-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1415154271973101572/mXXFwyM-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1223686898511577088/1626238366',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3524,
#     'favorite_count': 15912,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3524,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Jul 15 19:44:05 +0000 2021',
#    'id': 1415759092929503232,
#    'id_str': '1415759092929503232',
#    'text': 'RT @13sarahmurphy: Some days the unparalleled media protection for the worst Prime Minister of our lifetimes just floors me. \nWTF is it wit…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '13sarahmurphy',
#       'name': 'sarah murphy',
#       'id': 1158193640,
#       'id_str': '1158193640',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 431869456,
#     'id_str': '431869456',
#     'name': 'JazzySid 💙',
#     'screen_name': 'JazzySid',
#     'location': 'London, United Kingdom',
#     'description': 'We want the finest wines known to humanity.....and we want them here, and we want them now...! #WithnailAndI',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2150,
#     'friends_count': 4518,
#     'listed_count': 8,
#     'created_at': 'Thu Dec 08 19:42:29 +0000 2011',
#     'favourites_count': 271107,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 228683,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1363019379181555712/YNT3DFIj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1363019379181555712/YNT3DFIj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/431869456/1575112959',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 15 17:21:52 +0000 2021',
#     'id': 1415723300341309442,
#     'id_str': '1415723300341309442',
#     'text': 'Some days the unparalleled media protection for the worst Prime Minister of our lifetimes just floors me. \nWTF is i… https://t.co/rl2FWtqolr',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/rl2FWtqolr',
#        'expanded_url': 'https://twitter.com/i/web/status/1415723300341309442',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1158193640,
#      'id_str': '1158193640',
#      'name': 'sarah murphy',
#      'screen_name': '13sarahmurphy',
#      'location': '',
#      'description': 'welcome to my echo chamber - if you’re thoughtful, interesting, entertaining, open-minded.... otherwise, tbh, you’re not that welcome.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 71030,
#      'friends_count': 2679,
#      'listed_count': 145,
#      'created_at': 'Thu Feb 07 20:28:06 +0000 2013',
#      'favourites_count': 238894,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 39395,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1045972172903198721/nqfe1xoX_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1045972172903198721/nqfe1xoX_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1158193640/1576594471',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1020,
#     'favorite_count': 4017,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1020,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.069,
#   'max_id': 1415759110029651972,
#   'max_id_str': '1415759110029651972',
#   'next_results': '?max_id=1415759092929503231&q=hell&include_entities=1',
#   'query': 'hell',
#   'refresh_url': '?since_id=1415759110029651972&q=hell&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
