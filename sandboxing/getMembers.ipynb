# %%
import requests
import os
import json
import pandas as pd

# %%
#Security stuff - set the bearer token as an environment variable on your system for this to work.

bearer_token = os.environ.get("BEARER_TOKEN")

# %%
search_url = "https://api.twitter.com/1.1/lists/members.json"


parlListId = 864088912087715840
query_params = {'list_id': '{}'.format(parlListId), 'count': '5000'}

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def main():
    json_response = connect_to_endpoint(search_url, query_params)
#    return json.dumps(json_response, indent=4, sort_keys=True)
    return json_response

response = main()
# Out:
# 200

# %%
members = pd.DataFrame.from_dict(response['users'])

# %%
members
# Out:
#                       id               id_str                    name  \
# 0    1223994797834297350  1223994797834297350      Charbonneau Louise
# 1    1204044181037101057  1204044181037101057           Gerald Soroka
# 2    1198299741060239360  1198299741060239360             kyleseeback
# 3    1192858611879428097  1192858611879428097       Mike Kelloway, MP
# 4    1187132490684784642  1187132490684784642           Louise Chabot
# ..                   ...                  ...                     ...
# 316             16014404             16014404       Stéphane Bergeron
# 317             15810950             15810950       Matt Jeneroux, MP
# 318             14538949             14538949  Michelle Rempel Garner
# 319             14260960             14260960          Justin Trudeau
# 320              3358671              3358671              Ken Hardie
#
#          screen_name                  location  \
# 0    CharbonneauLou5
# 1     GeraldSorokaMP
# 2        kyleseeback
# 3       mikekelloway  Cape Breton, Nova Scotia
# 4     LouiseChabotBQ
# ..               ...                       ...
# 316        sbergeron
# 317         jeneroux           Alberta, Canada
# 318   MichelleRempel          Calgary, Canada
# 319    JustinTrudeau                  Papineau
# 320        KenHardie                Surrey, BC
#
#                                            description  \
# 0    Députée du Bloc Québécois à Trois-Rivières, je...
# 1                                    MP for Yellowhead
# 2    The Member of Parliament for Dufferin Caledon....
# 3          Member of Parliament for Cape Breton-Canso.
# 4    Députée du @BlocQuebecois dans Thérèse-de Blai...
# ..                                                 ...
# 316  Député fédéral de Montarville; ex-député fédér...
# 317          Member of Parliament, Edmonton Riverbend.
# 318
# 319  Father, husband, 23rd Prime Minister of Canada...
# 320  Ken Hardie, Member of Parliament for Fleetwood...
#
#                          url  \
# 0                       None
# 1    https://t.co/r2ne9Z5NJE
# 2    https://t.co/nuuFh6GhpC
# 3                       None
# 4    https://t.co/xkvZSwkuPl
# ..                       ...
# 316                     None
# 317  https://t.co/hDlqzlO1PC
# 318  https://t.co/pwr2ZHoRzs
# 319  https://t.co/NJdKCDAm9d
# 320  https://t.co/CXGN363hmN
#
#                                               entities  protected  \
# 0                        {'description': {'urls': []}}      False
# 1    {'url': {'urls': [{'url': 'https://t.co/r2ne9Z...      False
# 2    {'url': {'urls': [{'url': 'https://t.co/nuuFh6...      False
# 3                        {'description': {'urls': []}}      False
# 4    {'url': {'urls': [{'url': 'https://t.co/xkvZSw...      False
# ..                                                 ...        ...
# 316                      {'description': {'urls': []}}      False
# 317  {'url': {'urls': [{'url': 'https://t.co/hDlqzl...      False
# 318  {'url': {'urls': [{'url': 'https://t.co/pwr2ZH...      False
# 319  {'url': {'urls': [{'url': 'https://t.co/NJdKCD...      False
# 320  {'url': {'urls': [{'url': 'https://t.co/CXGN36...      False
#
#      followers_count  ...  profile_use_background_image  has_extended_profile  \
# 0                184  ...                          True                 False
# 1                399  ...                          True                 False
# 2               1050  ...                          True                 False
# 3                735  ...                          True                 False
# 4                494  ...                          True                 False
# ..               ...  ...                           ...                   ...
# 316            13547  ...                          True                 False
# 317             7466  ...                          True                 False
# 318           131639  ...                          True                  True
# 319          5674290  ...                         False                 False
# 320             4608  ...                          True                  True
#
#     default_profile  default_profile_image following follow_request_sent  \
# 0              True                  False      None                None
# 1              True                  False      None                None
# 2              True                  False      None                None
# 3              True                  False      None                None
# 4              True                  False      None                None
# ..              ...                    ...       ...                 ...
# 316           False                  False      None                None
# 317           False                  False      None                None
# 318            True                  False      None                None
# 319           False                  False      None                None
# 320           False                  False      None                None
#
#      notifications  translator_type  withheld_in_countries  \
# 0             None             none                     []
# 1             None             none                     []
# 2             None             none                     []
# 3             None             none                     []
# 4             None             none                     []
# ..             ...              ...                    ...
# 316           None             none                     []
# 317           None             none                     []
# 318           None             none                     []
# 319           None             none                     []
# 320           None             none                     []
#
#                                     profile_banner_url
# 0                                                  NaN
# 1    https://pbs.twimg.com/profile_banners/12040441...
# 2    https://pbs.twimg.com/profile_banners/11982997...
# 3    https://pbs.twimg.com/profile_banners/11928586...
# 4    https://pbs.twimg.com/profile_banners/11871324...
# ..                                                 ...
# 316  https://pbs.twimg.com/profile_banners/16014404...
# 317  https://pbs.twimg.com/profile_banners/15810950...
# 318  https://pbs.twimg.com/profile_banners/14538949...
# 319  https://pbs.twimg.com/profile_banners/14260960...
# 320  https://pbs.twimg.com/profile_banners/3358671/...
#
# [321 rows x 44 columns]

# %%
list(members['screen_name'])
# Out:
# ['CharbonneauLou5',
#  'GeraldSorokaMP',
#  'kyleseeback',
#  'mikekelloway',
#  'LouiseChabotBQ',
#  'ClaudeDBF_bq',
#  'MumilaaqQaqqaq',
#  'AnnieKoutrakis',
#  'JaimeBattiste',
#  'PatrickBWeiler',
#  'SameerZuberi',
#  'MSidhuLiberal',
#  'LucDesiletsBQ',
#  'TurnbullWhitby',
#  'MHGaudreauBQ',
#  'JeremyPatzerMP',
#  'AlexRuff17',
#  'ScotDavidsonMP',
#  'MPDerekSloan',
#  'JulieVignolaBL',
#  'GregMcLeanYYC',
#  'ChrisLewisEssex',
#  'DaveEppCKL',
#  'PLawrenceMP',
#  'BradRedekopp',
#  'richardmartelpc',
#  'DougShipleyBSOM',
#  'Lianne_Rood',
#  'PatriciaLattan3',
#  'MarilynGladuSL',
#  'SimonMarcilQc',
#  'BobBenzen',
#  'IqraKhalidMP',
#  'DLeBlancNB',
#  'GlenMotz',
#  'Joelgodinpjc',
#  'rosemarie_falk',
#  'ziad_aboultaif',
#  'm_pauze',
#  'PeterFonsecaMP',
#  'ATherrienBQ',
#  'RachaelHarderMP',
#  'FilomenaTassi',
#  'TerryDowdall',
#  'sergecormierlib',
#  'GillMarilene',
#  'marwantabbaramp',
#  'ArnoldViersen',
#  'TerrySheehanMP',
#  'Gabriel_SMarie',
#  'GinettePT',
#  'PatFinniganMP',
#  'KevinWaugh_CPC',
#  'F_ElKhoury',
#  'KellyMcCauleyMP',
#  'McDonald4Avalon',
#  'MMcLeodNWT',
#  'BlanchetteMax',
#  'BillBlair',
#  'SoniaLiberal',
#  'stephanelauzon5',
#  'DiLebouthillier',
#  'GenereuxBernard',
#  'MartinBowRiver',
#  'RaquelDancho',
#  'yvesperronbq',
#  'ToddDohertyMP',
#  'JenOConnell_',
#  'BobBratina',
#  'michelboudrias',
#  'ShannonStubbsMP',
#  'YRobillardPLC',
#  'Shaun_Chen',
#  'LefebvrePaul',
#  'HonAhmedHussen',
#  'adhillonDLL',
#  'CQualtro',
#  'jyduclos',
#  'MorrisseyEgmont',
#  'trudel_denis',
#  'darrellsamson',
#  'KateYoungMP',
#  'TracyGrayKLC',
#  'BernJordanMP',
#  'BardishKW',
#  'TimLouisKitCon',
#  'RajSaini4KitCen',
#  'Daniel_Blaikie',
#  'JonathanWNV',
#  'PatKelly_MP',
#  'krimichaudbq',
#  'JeanYip3',
#  'HonEdFast',
#  'LeonaAlleslev',
#  'Yasmin_Ratansi',
#  'ChristineNorm',
#  'SalmaZahid15',
#  'YaaraSaks',
#  'AryaCanada',
#  'jimcarr_wpg',
#  'Webber4Confed',
#  'DavidYurdiga',
#  'RonLiepert',
#  'pablorodriguez',
#  'MajidJowhari',
#  'MPTedFalk',
#  'MichaelChongMP',
#  'TOAdamVaughan',
#  'Laurel_BC',
#  'Cooper4SAE',
#  'GaryAVidal',
#  'beynate',
#  'JulieDzerowicz',
#  'gary_srp',
#  'AliEhsassi',
#  'MarcMillerVM',
#  'EmmanuelDubourg',
#  'BobSaroya',
#  'BenLobbMP',
#  'StephanieKusie',
#  'JenicaAtwin',
#  'FP_Champagne',
#  'LarryMaguireMP',
#  'AHousefather',
#  'ZannLenore',
#  'cathayw',
#  'KentThornhillMP',
#  'handongontario',
#  'JudySgroMP',
#  'DavidLametti',
#  'KerryLynneFindl',
#  'BradleyVis',
#  'RonMcKinnonLib',
#  'RichardBragdon',
#  'jameskcumming',
#  'SeanFraserMP',
#  'marty_morantz',
#  'PattyHajdu',
#  'VBadawey',
#  'MelArnoldMP',
#  'randeepssarai',
#  'WillAAmos',
#  'Puglaas',
#  'mclaudebibeau',
#  'DaveMacKenzieMP',
#  'CandiceBergenMP',
#  'CanningsNDP',
#  'Alduceppe',
#  'Francis_Drouin',
#  'MonaFortier',
#  'sangharamesh',
#  'pfragiskatos',
#  'JennyKwanBC',
#  'LloydLongfield',
#  'MichaelKramSK',
#  'XBarsalouDuval',
#  'sduvall07',
#  'viraniarif',
#  'SPSTremblay',
#  'ChurenceRogers',
#  'MaryamMonsef',
#  'L_MacAulay',
#  'SherryRomanado',
#  'AnitaOakville',
#  '_DebSchulte',
#  'takovanpopta',
#  'luctheriaultbq',
#  'WayneLongSJ',
#  'mflalonde',
#  'Chris_Bittle',
#  'AlainRayes',
#  'HarjitSajjan',
#  'PierrePaulHus',
#  'DarrenFisherNS',
#  'BerubeABJNE',
#  'juliedabrusin',
#  'Eric_Melillo',
#  'PeterSchiefke',
#  'LeahGazan',
#  'martchampoux',
#  'MBDan7',
#  'JohnWilliamson_',
#  'marcomendicino',
#  'RhealFortin',
#  'MikeBarrettON',
#  'erinotoole',
#  'HelenaJaczek',
#  'WarrenSteinley',
#  'RachelBendayan',
#  'ScottReidCPC',
#  'SvenTrueNorth',
#  'robmorrisonmp',
#  's_guilbeault',
#  'LMathys',
#  'markstrahl',
#  'Irek_K',
#  'JackHarrisNDP',
#  'emlambropoulos',
#  'A_Larouche_Shef',
#  'DavidMcGuinty',
#  'earl_dreeshen',
#  'fsorbara',
#  'bruce_stanton',
#  'Phil4Brant',
#  'AliceWongCanada',
#  'KirstyDuncanMP',
#  'JohnBarlowMP',
#  'karen_vecchio',
#  'LucBerthold',
#  'tomkmiec',
#  'r_garrison',
#  'RmdKenny',
#  'mariosimardbq',
#  'SeanCaseyLPC',
#  'Jamie_Schmale',
#  'AndrewScheer',
#  'AMacGregor4CML',
#  'theJagmeetSingh',
#  'AlexandraBrStL',
#  'MarcDalton',
#  'JohnMcKayLib',
#  'DeanAllisonMP',
#  'PierrePoilievre',
#  'YvonneJJones',
#  'RobMoore_CPC',
#  'gagansikand',
#  'GarnettGenuis',
#  'stbstvdan',
#  'NavdeepSBains',
#  'KamalKheraLib',
#  'seblemire',
#  'CharlieAngusNDP',
#  'GordJohns',
#  'JoelLightbound',
#  'Kevin_Lamoureux',
#  'PamDamoff',
#  'cafreeland',
#  'ScarpaleggiaLSL',
#  'alexboulerice',
#  'TimUppal',
#  'karenmccrimmon',
#  'bobzimmermp',
#  'taylorbachrach',
#  'ScottAAitchison',
#  'Scott_Simms',
#  'TerryDuguid',
#  'AnthonyRota',
#  'stevenmackinnon',
#  'Mario_Beaulieu',
#  'MarcSerreMP',
#  'AndyFillmoreHFX',
#  'MarkGerretsen',
#  'BlaineFCalkins',
#  'KerryDiotte',
#  'cathmckenna',
#  'SorayaMartinezF',
#  'MikeLakeMP',
#  'jasrajshallan',
#  'LarryBagnell',
#  'NeilREllis',
#  'RABlaney',
#  'BShanahanLib',
#  'vankayak',
#  'IaconoMP',
#  'HMcPhersonMP',
#  'markhollandlib',
#  'dckurek',
#  'MarcGarneau',
#  'CdEntremontMP',
#  'geoffregan',
#  'HonStevenBlaney',
#  'Cathy_McLeod',
#  'DavidSweetMP',
#  'paulmanly',
#  'WayneEaster',
#  'Rob_Oliphant',
#  'ColinCarrieCPC',
#  'karinagould',
#  'CarolHughesMP',
#  '_BryanMay',
#  'rubysahotalib',
#  'Yvan_Baker',
#  'MarciIen',
#  'chriswarkentin',
#  'GregFergus',
#  'jamesbezan',
#  'anitavandenbeld',
#  'Carolyn_Bennett',
#  'sukhdhaliwal',
#  'yfblanchet',
#  'JohnBrassardCPC',
#  'gerarddeltell',
#  'RandyHoback',
#  'JohnNaterMP',
#  'j_maloney',
#  'mary_ng',
#  'KellyBlockmp',
#  'ctochor',
#  'melaniejoly',
#  'HedyFry',
#  'DaneLIoydMP',
#  'EricDuncanSDSG',
#  'BlakeRichardsMP',
#  'SeamusORegan',
#  'Gudie',
#  'OmarAlghabra',
#  'BrianMasseMP',
#  'TonyVanBynen',
#  'MPJulian',
#  'nikiashton',
#  'MatthewGreenNDP',
#  'terrybeech',
#  'DanAlbas',
#  'ElizabethMay',
#  'DonDavies',
#  'JoyceMurray',
#  'sbergeron',
#  'jeneroux',
#  'MichelleRempel',
#  'JustinTrudeau',
#  'KenHardie']

# %%
def getMembers():
    response = main()
    members = pd.DataFrame.from_dict(response['users'])
    return list(members['screen_name'])

# %%
getMembers()
# Out:
# 200
# ['CharbonneauLou5',
#  'GeraldSorokaMP',
#  'kyleseeback',
#  'mikekelloway',
#  'LouiseChabotBQ',
#  'ClaudeDBF_bq',
#  'MumilaaqQaqqaq',
#  'AnnieKoutrakis',
#  'JaimeBattiste',
#  'PatrickBWeiler',
#  'SameerZuberi',
#  'MSidhuLiberal',
#  'LucDesiletsBQ',
#  'TurnbullWhitby',
#  'MHGaudreauBQ',
#  'JeremyPatzerMP',
#  'AlexRuff17',
#  'ScotDavidsonMP',
#  'MPDerekSloan',
#  'JulieVignolaBL',
#  'GregMcLeanYYC',
#  'ChrisLewisEssex',
#  'DaveEppCKL',
#  'PLawrenceMP',
#  'BradRedekopp',
#  'richardmartelpc',
#  'DougShipleyBSOM',
#  'Lianne_Rood',
#  'PatriciaLattan3',
#  'MarilynGladuSL',
#  'SimonMarcilQc',
#  'BobBenzen',
#  'IqraKhalidMP',
#  'DLeBlancNB',
#  'GlenMotz',
#  'Joelgodinpjc',
#  'rosemarie_falk',
#  'ziad_aboultaif',
#  'm_pauze',
#  'PeterFonsecaMP',
#  'ATherrienBQ',
#  'RachaelHarderMP',
#  'FilomenaTassi',
#  'TerryDowdall',
#  'sergecormierlib',
#  'GillMarilene',
#  'marwantabbaramp',
#  'ArnoldViersen',
#  'TerrySheehanMP',
#  'Gabriel_SMarie',
#  'GinettePT',
#  'PatFinniganMP',
#  'KevinWaugh_CPC',
#  'F_ElKhoury',
#  'KellyMcCauleyMP',
#  'McDonald4Avalon',
#  'MMcLeodNWT',
#  'BlanchetteMax',
#  'BillBlair',
#  'SoniaLiberal',
#  'stephanelauzon5',
#  'DiLebouthillier',
#  'GenereuxBernard',
#  'MartinBowRiver',
#  'RaquelDancho',
#  'yvesperronbq',
#  'ToddDohertyMP',
#  'JenOConnell_',
#  'BobBratina',
#  'michelboudrias',
#  'ShannonStubbsMP',
#  'YRobillardPLC',
#  'Shaun_Chen',
#  'LefebvrePaul',
#  'HonAhmedHussen',
#  'adhillonDLL',
#  'CQualtro',
#  'jyduclos',
#  'MorrisseyEgmont',
#  'trudel_denis',
#  'darrellsamson',
#  'KateYoungMP',
#  'TracyGrayKLC',
#  'BernJordanMP',
#  'BardishKW',
#  'TimLouisKitCon',
#  'RajSaini4KitCen',
#  'Daniel_Blaikie',
#  'JonathanWNV',
#  'PatKelly_MP',
#  'krimichaudbq',
#  'JeanYip3',
#  'HonEdFast',
#  'LeonaAlleslev',
#  'Yasmin_Ratansi',
#  'ChristineNorm',
#  'SalmaZahid15',
#  'YaaraSaks',
#  'AryaCanada',
#  'jimcarr_wpg',
#  'Webber4Confed',
#  'DavidYurdiga',
#  'RonLiepert',
#  'pablorodriguez',
#  'MajidJowhari',
#  'MPTedFalk',
#  'MichaelChongMP',
#  'TOAdamVaughan',
#  'Laurel_BC',
#  'Cooper4SAE',
#  'GaryAVidal',
#  'beynate',
#  'JulieDzerowicz',
#  'gary_srp',
#  'AliEhsassi',
#  'MarcMillerVM',
#  'EmmanuelDubourg',
#  'BobSaroya',
#  'BenLobbMP',
#  'StephanieKusie',
#  'JenicaAtwin',
#  'FP_Champagne',
#  'LarryMaguireMP',
#  'AHousefather',
#  'ZannLenore',
#  'cathayw',
#  'KentThornhillMP',
#  'handongontario',
#  'JudySgroMP',
#  'DavidLametti',
#  'KerryLynneFindl',
#  'BradleyVis',
#  'RonMcKinnonLib',
#  'RichardBragdon',
#  'jameskcumming',
#  'SeanFraserMP',
#  'marty_morantz',
#  'PattyHajdu',
#  'VBadawey',
#  'MelArnoldMP',
#  'randeepssarai',
#  'WillAAmos',
#  'Puglaas',
#  'mclaudebibeau',
#  'DaveMacKenzieMP',
#  'CandiceBergenMP',
#  'CanningsNDP',
#  'Alduceppe',
#  'Francis_Drouin',
#  'MonaFortier',
#  'sangharamesh',
#  'pfragiskatos',
#  'JennyKwanBC',
#  'LloydLongfield',
#  'MichaelKramSK',
#  'XBarsalouDuval',
#  'sduvall07',
#  'viraniarif',
#  'SPSTremblay',
#  'ChurenceRogers',
#  'MaryamMonsef',
#  'L_MacAulay',
#  'SherryRomanado',
#  'AnitaOakville',
#  '_DebSchulte',
#  'takovanpopta',
#  'luctheriaultbq',
#  'WayneLongSJ',
#  'mflalonde',
#  'Chris_Bittle',
#  'AlainRayes',
#  'HarjitSajjan',
#  'PierrePaulHus',
#  'DarrenFisherNS',
#  'BerubeABJNE',
#  'juliedabrusin',
#  'Eric_Melillo',
#  'PeterSchiefke',
#  'LeahGazan',
#  'martchampoux',
#  'MBDan7',
#  'JohnWilliamson_',
#  'marcomendicino',
#  'RhealFortin',
#  'MikeBarrettON',
#  'erinotoole',
#  'HelenaJaczek',
#  'WarrenSteinley',
#  'RachelBendayan',
#  'ScottReidCPC',
#  'SvenTrueNorth',
#  'robmorrisonmp',
#  's_guilbeault',
#  'LMathys',
#  'markstrahl',
#  'Irek_K',
#  'JackHarrisNDP',
#  'emlambropoulos',
#  'A_Larouche_Shef',
#  'DavidMcGuinty',
#  'earl_dreeshen',
#  'fsorbara',
#  'bruce_stanton',
#  'Phil4Brant',
#  'AliceWongCanada',
#  'KirstyDuncanMP',
#  'JohnBarlowMP',
#  'karen_vecchio',
#  'LucBerthold',
#  'tomkmiec',
#  'r_garrison',
#  'RmdKenny',
#  'mariosimardbq',
#  'SeanCaseyLPC',
#  'Jamie_Schmale',
#  'AndrewScheer',
#  'AMacGregor4CML',
#  'theJagmeetSingh',
#  'AlexandraBrStL',
#  'MarcDalton',
#  'JohnMcKayLib',
#  'DeanAllisonMP',
#  'PierrePoilievre',
#  'YvonneJJones',
#  'RobMoore_CPC',
#  'gagansikand',
#  'GarnettGenuis',
#  'stbstvdan',
#  'NavdeepSBains',
#  'KamalKheraLib',
#  'seblemire',
#  'CharlieAngusNDP',
#  'GordJohns',
#  'JoelLightbound',
#  'Kevin_Lamoureux',
#  'PamDamoff',
#  'cafreeland',
#  'ScarpaleggiaLSL',
#  'alexboulerice',
#  'TimUppal',
#  'karenmccrimmon',
#  'bobzimmermp',
#  'taylorbachrach',
#  'ScottAAitchison',
#  'Scott_Simms',
#  'TerryDuguid',
#  'AnthonyRota',
#  'stevenmackinnon',
#  'Mario_Beaulieu',
#  'MarcSerreMP',
#  'AndyFillmoreHFX',
#  'MarkGerretsen',
#  'BlaineFCalkins',
#  'KerryDiotte',
#  'cathmckenna',
#  'SorayaMartinezF',
#  'MikeLakeMP',
#  'jasrajshallan',
#  'LarryBagnell',
#  'NeilREllis',
#  'RABlaney',
#  'BShanahanLib',
#  'vankayak',
#  'IaconoMP',
#  'HMcPhersonMP',
#  'markhollandlib',
#  'dckurek',
#  'MarcGarneau',
#  'CdEntremontMP',
#  'geoffregan',
#  'HonStevenBlaney',
#  'Cathy_McLeod',
#  'DavidSweetMP',
#  'paulmanly',
#  'WayneEaster',
#  'Rob_Oliphant',
#  'ColinCarrieCPC',
#  'karinagould',
#  'CarolHughesMP',
#  '_BryanMay',
#  'rubysahotalib',
#  'Yvan_Baker',
#  'MarciIen',
#  'chriswarkentin',
#  'GregFergus',
#  'jamesbezan',
#  'anitavandenbeld',
#  'Carolyn_Bennett',
#  'sukhdhaliwal',
#  'yfblanchet',
#  'JohnBrassardCPC',
#  'gerarddeltell',
#  'RandyHoback',
#  'JohnNaterMP',
#  'j_maloney',
#  'mary_ng',
#  'KellyBlockmp',
#  'ctochor',
#  'melaniejoly',
#  'HedyFry',
#  'DaneLIoydMP',
#  'EricDuncanSDSG',
#  'BlakeRichardsMP',
#  'SeamusORegan',
#  'Gudie',
#  'OmarAlghabra',
#  'BrianMasseMP',
#  'TonyVanBynen',
#  'MPJulian',
#  'nikiashton',
#  'MatthewGreenNDP',
#  'terrybeech',
#  'DanAlbas',
#  'ElizabethMay',
#  'DonDavies',
#  'JoyceMurray',
#  'sbergeron',
#  'jeneroux',
#  'MichelleRempel',
#  'JustinTrudeau',
#  'KenHardie']
