# %%
# %run ../functions/getMembers.py

# %%
getMembers()
# Out:
# 200
# ['CharbonneauLou5',
#  'GeraldSorokaMP',
#  'kyleseeback',
#  'mikekelloway',
#  'LouiseChabotBQ',
#  'ClaudeDBF_bq',
#  'MumilaaqQaqqaq',
#  'AnnieKoutrakis',
#  'JaimeBattiste',
#  'PatrickBWeiler',
#  'SameerZuberi',
#  'MSidhuLiberal',
#  'LucDesiletsBQ',
#  'TurnbullWhitby',
#  'MHGaudreauBQ',
#  'JeremyPatzerMP',
#  'AlexRuff17',
#  'ScotDavidsonMP',
#  'MPDerekSloan',
#  'JulieVignolaBL',
#  'GregMcLeanYYC',
#  'ChrisLewisEssex',
#  'DaveEppCKL',
#  'PLawrenceMP',
#  'BradRedekopp',
#  'richardmartelpc',
#  'DougShipleyBSOM',
#  'Lianne_Rood',
#  'PatriciaLattan3',
#  'MarilynGladuSL',
#  'SimonMarcilQc',
#  'BobBenzen',
#  'IqraKhalidMP',
#  'DLeBlancNB',
#  'GlenMotz',
#  'Joelgodinpjc',
#  'rosemarie_falk',
#  'ziad_aboultaif',
#  'm_pauze',
#  'PeterFonsecaMP',
#  'ATherrienBQ',
#  'RachaelHarderMP',
#  'FilomenaTassi',
#  'TerryDowdall',
#  'sergecormierlib',
#  'GillMarilene',
#  'marwantabbaramp',
#  'ArnoldViersen',
#  'TerrySheehanMP',
#  'Gabriel_SMarie',
# ...
